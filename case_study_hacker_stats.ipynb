# %%
import numpy as np

np.random.rand()
# Out:
# 0.9725378829185723

# %%
np.random.seed(123);
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.rand()
# Out:
# 0.44336770180121177

# %%
np.random.rand(123)
# Out:
# array([0.71560128, 0.41051979, 0.19100696, 0.96749431, 0.65075037,
#        0.86545985, 0.02524236, 0.26690581, 0.5020711 , 0.06744864,
#        0.99303326, 0.2364624 , 0.37429218, 0.21401191, 0.10544587,
#        0.23247979, 0.30061014, 0.63444227, 0.28123478, 0.36227676,
#        0.00594284, 0.36571913, 0.53388598, 0.16201584, 0.59743311,
#        0.29315247, 0.63205049, 0.02619661, 0.88759346, 0.01611863,
#        0.12695803, 0.77716246, 0.04589523, 0.71099869, 0.97104614,
#        0.87168293, 0.71016165, 0.95850974, 0.42981334, 0.87287891,
#        0.35595767, 0.92976365, 0.14877766, 0.94002901, 0.8327162 ,
#        0.84605484, 0.12392301, 0.5964869 , 0.01639248, 0.72118437,
#        0.00773751, 0.08482228, 0.22549841, 0.87512453, 0.36357632,
#        0.53995994, 0.56810321, 0.22546336, 0.57214677, 0.6609518 ,
#        0.29824539, 0.41862686, 0.45308892, 0.93235066, 0.58749375,
#        0.94825237, 0.55603475, 0.50056142, 0.00353221, 0.48088904,
#        0.927455  , 0.19836569, 0.05209113, 0.40677889, 0.37239648,
#        0.85715306, 0.02661112, 0.92014923, 0.680903  , 0.90422599,
#        0.60752907, 0.81195331, 0.33554387, 0.34956623, 0.38987423,
#        0.75479708, 0.36929117, 0.24221981, 0.93766836, 0.90801108,
#        0.34879732, 0.63463807, 0.27384221, 0.20611513, 0.33633953,
#        0.32709989, 0.8822761 , 0.82230381, 0.70962323, 0.95934523,
#        0.42254335, 0.24503304, 0.11739844, 0.30105336, 0.14526373,
#        0.0921861 , 0.6029322 , 0.36418745, 0.56457034, 0.19133572,
#        0.67690586, 0.21550545, 0.27802359, 0.74176042, 0.5597379 ,
#        0.33483641, 0.54298878, 0.6939847 , 0.91213212, 0.58071321,
#        0.23268638, 0.74669763, 0.77776902])

# %%
np.random.rand()
# Out:
# 0.200401314962654

# %%
np.random.rand()
# Out:
# 0.820574219677886

# %%
import numpy as np

ends = np.array([ 70,  94,  82,  66, 107,  49,  72, 116,  65,  78,  87,  47,  81,
        75,  56,  70,  77,  88,  55,  42,  74,  64,  63,  58,  70,  55,
        93,  98,  58,  60,  70,  70,  72,  71,  47,  78,  78,  79,  71,
        83,  71,  56,  63,  94,  49,  72,  63,  74,  61,  61,  79,  91,
        91,  95,  71,  86,  84,  73,  73,  67,  62,  38,  69,  76,  78,
        88,  80,  80,  91,  57,  65])

print(np.count_nonzero(ends >= 60) / len(ends))
# Out:
# 0

# %%
import numpy as py
# ?py.random

# %%
#coin toss, randomly generate either a 0 or a 1.
import numpy as np
np.random.seed(123);
coin = np.random.randint(0,2);
print(coin)
# Out:
# 0

# %%
#coin toss, randomly generate either a 0 or a 1.
import numpy as np
np.random.seed(123);
coin = np.random.randint(0,2);
if coin == 0:
    print('heads');
else:
    print('tails');
# Out:
# heads

# %%
#coin toss, randomly generate either a 0 or a 1.
import numpy as np
np.random.seed(123);
outcomes = [];
for x in range(10):# there are 10 coin tosses.
    coin = np.random.randint(0,2);
    if coin == 0:
        #print(outcomes.append('heads'));
        outcomes.append('heads');
    else:
        #print(outcomes.append('tails'));
        outcomes.append('tails');
print(outcomes);
# Out:
# ['heads', 'tails', 'heads', 'heads', 'heads', 'heads', 'heads', 'tails', 'tails', 'heads']

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(123);
all_walks = [];

#simulate random walk 500 times
for i in range(500):
    random_walk = [-1];
    for x in range(100):
        step = random_walk[-1];
        dice = np.random.randint(1, 7);
        if dice <= 2:
            step = max(0, step-1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7);
        if np.random.rand() <= 0.001:
            step = 0;
        random_walk.append(step);
    all_walks.append(random_walk);
    
    # create and plot np_aw_t
    np_aw_t = np.transpose(np.array(all_walks));
    
    # select last row from np_aw_t: ends
    ends = np.array(np_aw_t[-1]);
    
    # plot the histogram ends, display plot
    plt.hist(ends);
    plt.title("figure");
    plt.show();

# %%
## you're in a tall bldg, at the 50th floor.
## use a dice, and depending on it's call, you determine your movement.
## if dice is 1 or 2, go one floor down
## if 3,4 or 5, go one floor up.
## else throw dice again, and go the no. of floors given by the dice.
## print the movement and random variables of dice.

import numpy as np

# set seed, i still don't get this seed concept though.
np.random.seed(123); # what's the deal with 123??

floor = []; # initial floor.

#dice = [np.random.randint(1,7)];# dice randome b/w 1 to 6.

for x in range(10):# i want to test it with 10 tries
    # and track the movement.
    dice = [np.random.randint(1,7)];# dice randome b/w 1 to 6.
    if dice <= 2:
        floor[x+1] = floor[x]-1;
        floor.appends(floor[x+1]);
    elif dice < 6:
        #floor =  floor+1;
        floor[x+1] = floor[x]-1;
        floor.appends(floor[x+1]);
    else:
        #floor = floor + dice;
        floor[x+1] = floor[x] + dice;
print(floor);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-05d327607995> in <module>()
#      27     else:
#      28         #floor = floor + dice;
# ---> 29         floor[x+1] = floor[x] + dice;
#      30 print(floor);
#      31
#
# IndexError: list index out of range
