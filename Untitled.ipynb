# %%
import numpy as np
import matplotlib.pyplot as plt
from RBFN import RBFN

x = np.linspace(0,10,100)
y = np.sin(x)
model = RBFN(input_shape = 1, hidden_shape = 10)
model.fit(x,y)
y_pred = model.predict(x)

plt.plot(x,y,'b-',label='real')
plt.plot(x,y_pred,'r-',label='fit')
plt.legend(loc='upper right')
plt.title('Interpolation using a RBFN')
plt.show()

# %%
#pwd
import sys
sys.path
# Out:
# ['',
#  'C:\\Python27\\Scripts\\Python_for_DS\\my_py_libs',
#  'C:\\Python27\\Scripts\\Python_for_DS',
#  'C:\\WINDOWS\\SYSTEM32\\python27.zip',
#  'c:\\python27\\DLLs',
#  'c:\\python27\\lib',
#  'c:\\python27\\lib\\plat-win',
#  'c:\\python27\\lib\\lib-tk',
#  'c:\\python27',
#  'c:\\python27\\lib\\site-packages',
#  'c:\\python27\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Sai Kamat\\.ipython']

# %%
import os
os.getcwd()
# Out:
# 'C:\\Python27\\Scripts\\Python_for_DS'
